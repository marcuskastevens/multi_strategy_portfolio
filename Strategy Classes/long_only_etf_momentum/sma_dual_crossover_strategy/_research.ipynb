# %%
import pickle
import matplotlib.pyplot as plt
import backtest_tools.portfolio_tools as pt

# %%
# Import Strategy Class
from sma_dual_crossover_strategy_class import sma_dual_crossover_strategy

# %%
for i in range(0, 2):

    path = fr'C:\Users\marcu\Documents\Quant\Programming\Strategies\Beta Strategies\sma_dual_crossover_strategy_{i}.pickle'
    
    with open(path, 'rb') as handler:
        strategy = pickle.load(handler)
        strategy.performance_analysis()
        plt.show()
# Out:
# ['SPY', 'QQQ']
# ['SPY', 'QQQ']

# %%
strategy.strategy_performance_summary
# Out:
#                              Performance Summary
# Strategy Returns
# Sharpe Ratio                               0.662
# Drift Adjusted Sharpe Ratio                2.829
# CAGR                                       0.063
# Vol                                        0.100
# Sortino Ratio                              0.819
# Martin (Ulcer) Ratio                       0.887
# Omega Ratio                                0.997
# RR Ratio                                   1.144
# Win Rate                                   0.557
# Skew                                      -0.492
# Kurtosis                                  11.737
# Max Drawdown                              -0.202
# VaR - Laplace                             -0.024
# CVaR - Laplace                            -0.030

# %%
pt.performance_summary(strategy.strategy_returns)
# Out:
#                              Performance Summary
# Sharpe Ratio                               0.662
# Drift Adjusted Sharpe Ratio                1.746
# CAGR                                       0.098
# Vol                                        0.161
# Sortino Ratio                              0.819
# Martin (Ulcer) Ratio                       0.899
# Omega Ratio                                1.050
# RR Ratio                                   1.144
# Win Rate                                   0.557
# Skew                                      -0.492
# Kurtosis                                  11.737
# Max Drawdown                              -0.311
# VaR - Laplace                             -0.041
# CVaR - Laplace                            -0.052
