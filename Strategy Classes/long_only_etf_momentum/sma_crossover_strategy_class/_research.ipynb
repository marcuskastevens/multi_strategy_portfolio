# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Import Strategy Class
from sma_crossover_strategy_class import sma_crossover_strategy

# %%
for i in range(0, 1):

    path = fr'C:\Users\marcu\Documents\Quant\Programming\Strategies\Beta Strategies\sma_crossover_strategy_{i}.pickle'
    
    with open(path, 'rb') as handler:
        strategy = pickle.load(handler)
        strategy.performance_analysis()
        plt.show()
# Out:
# ['SPY', 'QQQ']

# %%
strategy.strategy_performance_summary
# Out:
#                              Performance Summary
# Strategy Returns
# Sharpe Ratio                               0.601
# Drift Adjusted Sharpe Ratio                5.285
# CAGR                                       0.057
# Vol                                        0.100
# Sortino Ratio                              0.741
# Martin (Ulcer) Ratio                       0.817
# Omega Ratio                                0.985
# RR Ratio                                   1.128
# Win Rate                                   0.555
# Skew                                      -0.603
# Kurtosis                                  12.255
# Max Drawdown                              -0.191
# VaR - Laplace                             -0.025
# CVaR - Laplace                            -0.031
