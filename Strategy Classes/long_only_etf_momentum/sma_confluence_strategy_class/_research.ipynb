# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import backtest_tools.portfolio_tools as pt

# %%
# Import Strategy Class
from sma_confluence_strategy_class import sma_confluence_strategy

# %%
for i in range(0, 1):

    path = fr'C:\Users\marcu\Documents\Quant\Programming\Strategies\Beta Strategies\sma_confluence_strategy_{i}.pickle'
    
    with open(path, 'rb') as handler:
        strategy = pickle.load(handler)
        strategy.performance_analysis()
        plt.show()
# Out:
# ['SPY', 'QQQ']

# %%
pt.performance_summary(strategy.strategy_returns)
# Out:
#                              Performance Summary
# Sharpe Ratio                               0.588
# Drift Adjusted Sharpe Ratio                2.597
# CAGR                                       0.074
# Vol                                        0.137
# Sortino Ratio                              0.726
# Martin (Ulcer) Ratio                       0.739
# Omega Ratio                                1.019
# RR Ratio                                   1.128
# Win Rate                                   0.555
# Skew                                      -0.729
# Kurtosis                                  14.949
# Max Drawdown                              -0.245
# VaR - Laplace                             -0.033
# CVaR - Laplace                            -0.042
